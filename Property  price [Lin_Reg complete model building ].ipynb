# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Load Data

# %%
pr= pd.read_csv(r"C:\Users\amans\Downloads\Property_Price_Train.csv")       # r means row data

# %%
pr.shape
# Out:
# (1459, 81)

# %%
pr.head()
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type Lot_Configuration Property_Slope  \
# 0            Reg          Lvl       AllPub                 I             GS
# 1            Reg          Lvl       AllPub              FR2P             GS
# 2            IR1          Lvl       AllPub                 I             GS
# 3            IR1          Lvl       AllPub                 C             GS
# 4            IR1          Lvl       AllPub              FR2P             GS
#
# ...

# %%
pr.isnull().sum()
# Out:
# Id                              0
# Building_Class                  0
# Zoning_Class                    0
# Lot_Extent                    259
# Lot_Size                        0
# Road_Type                       0
# Lane_Type                    1368
# Property_Shape                  0
# Land_Outline                    0
# Utility_Type                    0
# Lot_Configuration               0
# Property_Slope                  0
# Neighborhood                    0
# Condition1                      0
# Condition2                      0
# House_Type                      0
# House_Design                    0
# Overall_Material                0
# House_Condition                 0
# Construction_Year               0
# Remodel_Year                    0
# Roof_Design                     0
# Roof_Quality                    0
# Exterior1st                     0
# Exterior2nd                     0
# Brick_Veneer_Type               8
# Brick_Veneer_Area               8
# ...

# %%
pr.isnull().sum()[pr.isnull().sum()>0]
# Out:
# Lot_Extent                259
# Lane_Type                1368
# Brick_Veneer_Type           8
# Brick_Veneer_Area           8
# Basement_Height            37
# Basement_Condition         37
# Exposure_Level             38
# BsmtFinType1               37
# BsmtFinType2               38
# Electrical_System           1
# Fireplace_Quality         689
# Garage                     81
# Garage_Built_Year          81
# Garage_Finish_Year         81
# Garage_Quality             81
# Garage_Condition           81
# Pool_Quality             1452
# Fence_Quality            1178
# Miscellaneous_Feature    1405
# dtype: int64

# %%
pr.Lane_Type = pr.Lane_Type.fillna('Grvl')

# %%
pr.Fireplace_Quality = pr.Fireplace_Quality.fillna('Gd')

# %%
pr.Pool_Quality = pr.Pool_Quality.fillna("No")

# %%
pr.Fence_Quality=pr.Fence_Quality.fillna("No")

# %%
pr.Miscellaneous_Feature = pr.Miscellaneous_Feature.fillna("No")

# %%
pr.Brick_Veneer_Type=pr.Brick_Veneer_Type.fillna('None')

# %%
pr.Brick_Veneer_Area = pr.Brick_Veneer_Area.fillna(pr.Brick_Veneer_Area.mean())

# %%
pr.Lot_Extent=pr.Lot_Extent.fillna(pr.Lot_Extent.mean())

# %%
pr.Basement_Height = pr.Basement_Height.fillna("TA")

# %%
pr.Basement_Condition =pr.Basement_Condition.fillna("TA")

# %%
pr.Exposure_Level =pr.Exposure_Level.fillna('No')

# %%
pr.BsmtFinType1 =pr.BsmtFinType1.fillna("Unf")

# %%
pr.BsmtFinType2 =pr.BsmtFinType1.fillna("Unf")

# %%
pr.Electrical_System = pr.Electrical_System.fillna("SBrkr")

# %%
pr.Garage =pr.Garage.fillna("Attchd")

# %%
pr.Garage_Built_Year=pr.Garage_Built_Year.fillna(pr.Garage_Built_Year.mean())

# %%
pr.Garage_Finish_Year=pr.Garage_Finish_Year.fillna("Unf")

# %%
pr.Garage_Quality =pr.Garage_Quality .fillna("TA")

# %%
pr.Garage_Condition=pr.Garage_Condition.fillna("TA")

# %%
pr.isnull().sum()
# Out:
# Id                           0
# Building_Class               0
# Zoning_Class                 0
# Lot_Extent                   0
# Lot_Size                     0
# Road_Type                    0
# Lane_Type                    0
# Property_Shape               0
# Land_Outline                 0
# Utility_Type                 0
# Lot_Configuration            0
# Property_Slope               0
# Neighborhood                 0
# Condition1                   0
# Condition2                   0
# House_Type                   0
# House_Design                 0
# Overall_Material             0
# House_Condition              0
# Construction_Year            0
# Remodel_Year                 0
# Roof_Design                  0
# Roof_Quality                 0
# Exterior1st                  0
# Exterior2nd                  0
# Brick_Veneer_Type            0
# Brick_Veneer_Area            0
# Exterior_Material            0
# Exterior_Condition           0
# Foundation_Type              0
# ...

# %%
pr= pr.drop(['Id','Lane_Type','Fireplace_Quality','Pool_Quality','Fence_Quality','Miscellaneous_Feature'], axis=1)

# %%
 from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 75 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Building_Class             1459 non-null   int64
#  1   Zoning_Class               1459 non-null   object
#  2   Lot_Extent                 1459 non-null   float64
#  3   Lot_Size                   1459 non-null   int64
#  4   Road_Type                  1459 non-null   object
#  5   Property_Shape             1459 non-null   object
#  6   Land_Outline               1459 non-null   object
#  7   Utility_Type               1459 non-null   object
#  8   Lot_Configuration          1459 non-null   object
#  9   Property_Slope             1459 non-null   object
#  10  Neighborhood               1459 non-null   object
#  11  Condition1                 1459 non-null   object
#  12  Condition2                 1459 non-null   object
# ...

# %%
pr.select_dtypes(include=['object']).columns
# Out:
# Index(['Zoning_Class', 'Road_Type', 'Property_Shape', 'Land_Outline',
#        'Utility_Type', 'Lot_Configuration', 'Property_Slope', 'Neighborhood',
#        'Condition1', 'Condition2', 'House_Type', 'House_Design', 'Roof_Design',
#        'Roof_Quality', 'Exterior1st', 'Exterior2nd', 'Brick_Veneer_Type',
#        'Exterior_Material', 'Exterior_Condition', 'Foundation_Type',
#        'Basement_Height', 'Basement_Condition', 'Exposure_Level',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating_Type', 'Heating_Quality',
#        'Air_Conditioning', 'Electrical_System', 'Kitchen_Quality',
#        'Functional_Rate', 'Garage', 'Garage_Finish_Year', 'Garage_Quality',
#        'Garage_Condition', 'Pavedd_Drive', 'Sale_Type', 'Sale_Condition'],
#       dtype='object')

# %%
pr [pr.select_dtypes(include=['object']).columns ]
# Out:
#      Zoning_Class Road_Type Property_Shape Land_Outline Utility_Type  \
# 0             RLD     Paved            Reg          Lvl       AllPub
# 1             RLD     Paved            Reg          Lvl       AllPub
# 2             RLD     Paved            IR1          Lvl       AllPub
# 3             RLD     Paved            IR1          Lvl       AllPub
# 4             RLD     Paved            IR1          Lvl       AllPub
# 5             RLD     Paved            IR1          Lvl       AllPub
# 6             RLD     Paved            Reg          Lvl       AllPub
# 7             RLD     Paved            IR1          Lvl       AllPub
# 8             RMD     Paved            Reg          Lvl       AllPub
# 9             RLD     Paved            Reg          Lvl       AllPub
# 10            RLD     Paved            Reg          Lvl       AllPub
# 11            RLD     Paved            IR1          Lvl       AllPub
# 12            RLD     Paved            IR2          Lvl       AllPub
# ...

# %%
pr [pr.select_dtypes(include=['object']).columns ] = pr [pr.select_dtypes(include=['object']).columns ].apply(le.fit_transform)

# %%
from sklearn.model_selection import train_test_split

# %%
pr_train,pr_test = train_test_split(pr,test_size = .2)

# %%
pr_train.shape
# Out:
# (1167, 75)

# %%
pr_test.shape
# Out:
# (292, 75)

# %%
pr_train_x = pr_train.iloc[:  , 0 : 50]

# %%
pr_train_y = pr_train.iloc[:,-1]

# %%
pr_test_x = pr_test.iloc[:  , 0 : 50]

# %%
pr_test_y = pr_test.iloc[:,-1]

# %%
pr_train_x.head()
# Out:
#      Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  \
# 588              20             3        65.0     25095          1
# 192              20             3        68.0      9017          1
# 60               20             3        63.0     13072          1
# 410              20             3        68.0      9571          1
# 524              60             3        95.0     11787          1
#
#      Property_Shape  Land_Outline  Utility_Type  Lot_Configuration  \
# 588               0             2             0                  4
# 192               0             3             0                  4
# 60                3             3             0                  4
# 410               3             3             0                  4
# 524               0             3             0                  4
#
#      Property_Slope  Neighborhood  Condition1  Condition2  House_Type  \
# 588               2             4           2           2           0
# ...

# %%
pr_train_y.head()
# Out:
# 588    143000
# 192    192000
# 60     158000
# 410     60000
# 524    315750
# Name: Sale_Price, dtype: int64

# %%
pr_test_x.head()
# Out:
#       Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  \
# 147               60             3   70.045833      9505          1
# 1309              20             3   70.045833      7153          1
# 666               60             3   70.045833     18450          1
# 81               120             4   32.000000      4500          1
# 1338              60             3   95.000000     13450          1
#
#       Property_Shape  Land_Outline  Utility_Type  Lot_Configuration  \
# 147                0             3             0                  1
# 1309               3             3             0                  4
# 666                0             3             0                  4
# 81                 3             3             0                  2
# 1338               0             3             0                  0
#
#       Property_Slope  Neighborhood  Condition1  Condition2  House_Type  \
# 147                0             8           2           2           0
# ...

# %%
pr_test_y.head()
# Out:
# 147     222500
# 1309    179200
# 666     129000
# 81      153500
# 1338    200000
# Name: Sale_Price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(pr_train_x,pr_train_y)
# Out:
# LinearRegression()

# %%
lin_reg.score(pr_train_x,pr_train_y)
# Out:
# 0.8365451390910225

# %%
lin_reg.predict(pr_test_x)
# Out:
# array([228750.83029001, 181453.1544351 , 240691.14177508, 195459.78857963,
#        229491.93827413, 127424.6072446 , 229996.07755556, 142173.80569204,
#        247568.38720207, 226299.25802805, 242940.83187529, 189479.3936053 ,
#        348981.95232592, 195479.88737636, 230494.41539457, 209904.70344874,
#         96597.34727546, 355961.07882419, 198252.84528544, 188727.49846638,
#        220161.12349976, 260995.02631395, 154380.01754856, 154123.38808921,
#        214331.40445398, 103899.41362161, 106995.35137983, 198093.63448777,
#        207713.63020937, 204746.85211644, 206235.58630567, 136773.23167289,
#        247343.66637674, 140707.04563112, 167945.37235205, 173724.18832067,
#        163396.83978699, 173585.22845602, 182649.67276342, 135651.86348634,
#        118307.96711753, 219831.41773752, 115257.47728864, 304108.76731465,
#        199806.95379042, 173499.8443932 , 235337.80215622, 255664.13106782,
# ...

# %%
lin_reg.intercept_
# Out:
# -635818.0338984743

# %%
lin_reg.coef_
# Out:
# array([-1.27767720e+02, -7.22518392e+02, -1.30965779e+02,  3.56790854e-01,
#         5.67023395e+03, -2.03323247e+03,  3.22372121e+03, -2.66536375e-08,
#         1.96131491e+02,  8.57049387e+03,  4.52804381e+02, -1.32924298e+03,
#        -1.14261586e+04, -3.74360178e+03, -1.30756192e+03,  1.53520719e+04,
#         5.13320195e+03,  2.00250234e+02,  8.49110384e+01,  2.00906961e+03,
#         2.98681365e+04, -9.46122831e+02,  2.72447779e+02,  3.86897058e+03,
#         3.47577505e+01, -1.19463124e+04,  1.64164208e+03,  2.59045217e+03,
#        -1.12777085e+04,  1.48720044e+03, -4.11021696e+03, -4.39466601e+02,
#         6.23225570e+00, -4.39466601e+02,  6.91429390e+00, -4.21584855e+00,
#         8.93070109e+00, -8.33794874e+02, -1.57901709e+03,  2.95970559e+03,
#        -6.14037652e+02,  2.24329984e+01,  2.19879966e+01, -1.25862159e+01,
#         3.18347790e+01,  5.50631285e+03,  2.39209305e+02,  4.10565928e+03,
#         2.92591751e+03, -4.13115897e+03])

# %%
Rsquare = lin_reg.score(pr_train_x , pr_train_y)

# %%
N = pr_train_x.shape[0]

# %%
K = pr_train_x.shape[1]

# %%
Adj_Rsquare = 1-(1-Rsquare) * (N-1)/(N-K-1)

# %%
Adj_Rsquare
# Out:
# 0.8292218926345271

# %%
pred_train = lin_reg.predict(pr_train_x)

# %%
pred_train
# Out:
# array([243497.29990619, 227862.5474024 , 176922.16809577, ...,
#        513458.29484333, 123448.81874675, 190494.22342027])

# %%
len(pred_train)
# Out:
# 1167

# %%
pr_train_x.shape
# Out:
# (1167, 50)

# %%
pred_actual = pd.DataFrame({"Predicted" : pred_train ,
                            "Actual" : pr_train_y})

# %%
pred_actual
# Out:
#           Predicted  Actual
# 588   243497.299906  143000
# 192   227862.547402  192000
# 60    176922.168096  158000
# 410    98034.676681   60000
# 524   280852.598516  315750
# 1348  238147.519632  215000
# 362   213497.047141  198500
# 243   113046.713576  120000
# 1166  253930.518440  245350
# 871   179740.239638  200500
# 1129  123694.233929  140000
# 1079  126202.017568  126000
# 670   184690.001816  173500
# 220   215062.724484  204900
# 738   156143.889645  179000
# 904   117920.018469  125500
# 1358  173029.155565  177500
# 222   167322.765785  179900
# 771   120074.670455  102000
# 808   148319.211426  159950
# 469   199863.744083  187000
# 634   138032.009890  144000
# 26    115747.462529  134800
# 1292  142937.030837  107500
# 1107  228106.643518  274725
# 425   151969.940734  135000
# 489    90422.571031   86000
# 748   253639.588717  260400
# 3     157964.668371  140000
# 85    261206.760511  260000
# 408   257851.028656  280000
# 206   147559.106824  143900
# ...

# %%
error_train = pr_train_y - pred_train

# %%
error_train
# Out:
# 588    -100497.299906
# 192     -35862.547402
# 60      -18922.168096
# 410     -38034.676681
# 524      34897.401484
# 1348    -23147.519632
# 362     -14997.047141
# 243       6953.286424
# 1166     -8580.518440
# 871      20759.760362
# 1129     16305.766071
# 1079      -202.017568
# 670     -11190.001816
# 220     -10162.724484
# 738      22856.110355
# 904       7579.981531
# 1358      4470.844435
# 222      12577.234215
# 771     -18074.670455
# 808      11630.788574
# 469     -12863.744083
# 634       5967.990110
# 26       19052.537471
# 1292    -35437.030837
# 1107     46618.356482
# 425     -16969.940734
# 489      -4422.571031
# 748       6760.411283
# 3       -17964.668371
# 85       -1206.760511
# 408      22148.971344
# 206      -3659.106824
# 1140      8524.410470
# 811      -1691.571809
# 1244     37003.510806
# 321      26829.434196
# 4       -36267.289922
# 940     -24571.650189
# 480       -930.754074
# 41       19926.956528
# 250      11599.212924
# ...

# %%
import numpy as np

# %%
np.mean(error_train)
# Out:
# -2.1896455133686538e-10

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.hist(error_train ,edgecolor="k")
# Out:
# (array([  2.,   0.,   0.,   3.,  64., 937., 147.,  11.,   2.,   1.]),
#  array([-353458.29484333, -290602.39038171, -227746.4859201 ,
#         -164890.58145848, -102034.67699687,  -39178.77253526,
#           23677.13192636,   86533.03638797,  149388.94084959,
#          212244.8453112 ,  275100.74977281]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(error_train)
# Out:
# C:\Users\amans\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sale_Price', ylabel='Density'>

# %%
plt.plot(error_train , "*")
plt.axhline(y = np.mean(error_train)  , color="r")
plt.axhline(y = -3  , color="yellow")
plt.axhline(y = 3  , color="g")

# %%
sns.regplot(pred_actual.Actual,pred_actual.Predicted  , color="r")
# Out:
# C:\Users\amans\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Actual', ylabel='Predicted'>

# %%
feature_Slope= pd.DataFrame({"Features":pr_train_x.columns,
                            "Slope":lin_reg.coef_})

# %%
feature_Slope.sort_values("Slope" , ascending=False)
# Out:
#                      Features         Slope
# 20               Roof_Quality  2.986814e+04
# 15           Overall_Material  1.535207e+04
# 9              Property_Slope  8.570494e+03
# 4                   Road_Type  5.670234e+03
# 45  Underground_Full_Bathroom  5.506313e+03
# 16            House_Condition  5.133202e+03
# 47  Full_Bathroom_Above_Grade  4.105659e+03
# 23          Brick_Veneer_Type  3.868971e+03
# 6                Land_Outline  3.223721e+03
# 39           Air_Conditioning  2.959706e+03
# 48  Half_Bathroom_Above_Grade  2.925918e+03
# 27            Foundation_Type  2.590452e+03
# 19                Roof_Design  2.009070e+03
# 26         Exterior_Condition  1.641642e+03
# 29         Basement_Condition  1.487200e+03
# 10               Neighborhood  4.528044e+02
# 22                Exterior2nd  2.724478e+02
# 46  Underground_Half_Bathroom  2.392093e+02
# 17          Construction_Year  2.002502e+02
# 8           Lot_Configuration  1.961315e+02
# ...

# %%
pred_train = lin_reg.predict(pr_train_x)

# %%
pred_test = lin_reg.predict(pr_test_x)

# %%
pred_train
# Out:
# array([243497.29990619, 227862.5474024 , 176922.16809577, ...,
#        513458.29484333, 123448.81874675, 190494.22342027])

# %%
pred_test
# Out:
# array([228750.83029001, 181453.1544351 , 240691.14177508, 195459.78857963,
#        229491.93827413, 127424.6072446 , 229996.07755556, 142173.80569204,
#        247568.38720207, 226299.25802805, 242940.83187529, 189479.3936053 ,
#        348981.95232592, 195479.88737636, 230494.41539457, 209904.70344874,
#         96597.34727546, 355961.07882419, 198252.84528544, 188727.49846638,
#        220161.12349976, 260995.02631395, 154380.01754856, 154123.38808921,
#        214331.40445398, 103899.41362161, 106995.35137983, 198093.63448777,
#        207713.63020937, 204746.85211644, 206235.58630567, 136773.23167289,
#        247343.66637674, 140707.04563112, 167945.37235205, 173724.18832067,
#        163396.83978699, 173585.22845602, 182649.67276342, 135651.86348634,
#        118307.96711753, 219831.41773752, 115257.47728864, 304108.76731465,
#        199806.95379042, 173499.8443932 , 235337.80215622, 255664.13106782,
# ...

# %%
error_train = pr_train_y - pred_train

# %%
error_test = pr_test_y - pred_test

# %%
error_test
# Out:
# 147      -6250.830290
# 1309     -2253.154435
# 666    -111691.141775
# 81      -41959.788580
# 1338    -29491.938274
# 1130      7575.392755
# 283      14603.922444
# 1227      4826.194308
# 280     -19068.387202
# 604      -5299.258028
# 452     -38940.831875
# 781     -13579.393605
# 1142     75888.047674
# 616     -12279.887376
# 1196    -11284.415395
# 1277    -12004.703449
# 676      -9597.347275
# 477      24038.921176
# 605       6747.154715
# 516     -30727.498466
# 453     -10161.123500
# 1310     74004.973686
# 892        119.982451
# 893      10876.611911
# 415     -33197.404454
# 609      14600.586378
# 71       22504.648620
# 1       -16593.634488
# 939      36686.369791
# 924       2753.147884
# 1284    -37235.586306
# 19        2226.768327
# 753      28156.333623
# 1160      5292.954369
# 1341    -12945.372352
# 285      -9024.188321
# 1083     -3396.839787
# 891      -1085.228456
# 1189      6350.327237
# 863      -3151.863486
# 723      16692.032882
# ...

# %%
MAE = np.mean(np.abs(error_test))

# %%
MAE
# Out:
# 19924.05923298109

# %%
MSE = np.mean(np.square(error_test))

# %%
MSE
# Out:
# 858480906.3882834

# %%
RMSE = np.sqrt(MSE)

# %%
RMSE
# Out:
# 29299.84481850174

# %%
MAPE = np.mean(np.abs(error_test * 100/ pr_test_y))

# %%
MAPE
# Out:
# 12.06471722135935

# %%
Acc = 100-MAPE

# %%
Acc
# Out:
# 87.93528277864066

# %% [markdown]
# # Remove Outliers

# %%
def remove_outliers(df, col,k=2):
    mean = df[col].mean()
    global df1
    sd = df[col].std()
    final_list=[x for x in df[col] if (x > mean - k * sd)]
    final_list=[x for x in final_list if (x < mean + k * sd)]
    df1=df.loc[df[col].isin(final_list)]
    print(df1.shape)

# %%
remove_outliers(pr, "Sale_Price" , k=2)     # k is std deviation.
# Out:
# (1396, 75)

# %%
pr = df1
